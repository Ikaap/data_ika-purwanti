# %% [markdown]
# # Soal Prioritas 1

# %% [markdown]
# ## 1. Ekstrak data transaksi e-commerce dari file CSV dan data produk dari file Excel

# %% [markdown]
# ### 1.1 Install Library

# %%
# %pip install pandas
# %pip install openpyxl
# Out:
# ...
#
# ...
#
# ...

# %% [markdown]
# ### 1.2 Import Library

# %%
import pandas as pd
from IPython.display import display

# %% [markdown]
# ### 1.3 Load Data dan Display Data

# %%
df_transactions = pd.read_csv('source/transactions.csv', sep=',')
df_products = pd.read_excel('source/products.xlsx')

print("Data Transaction dari file 'transactions.csv'")
display(df_transactions)

print("Data Product dari file 'products.xlsx'")
display(df_products)
# Out:
# Data Transaction dari file 'transactions.csv'
#     Transaction ID  User ID                Item Name  Quantity  Value (USD)  \
# 0                1     1001               Smartphone         1       799.99
# 1                2     1002               Headphones         2       399.98
# 2                3     1003                   Laptop         1       999.99
# 3                4     1004        Bluetooth Speaker         1        79.99
# 4                5     1005               Smartwatch         1       299.99
# ..             ...      ...                      ...       ...          ...
# 95              96     1096         Baby Musical Toy         1        12.99
# 96              97     1097        Baby Floor Mirror         1        19.99
# 97              98     1098              Baby Mobile         1        29.99
# 98              99     1099  Baby Stroller Organizer         1        19.99
# 99             100     1100             Baby Sun Hat         1         9.99
#
# ...

# %% [markdown]
# ## 2. Gunakan pymysql untuk mengimpor data pelanggan dari database MySQL

# %% [markdown]
# ### 2.1 Install Library

# %%
# %pip install pymysql
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### 2.2 Import Library

# %%
from pymysql import connect

# %% [markdown]
# ### 2.3 Connection MySQL

# %%
connection = connect(
    host="localhost",
    port=3308,
    db="alta_task_data_ingestion",
    user="root",
    password=""
)

cursor = connection.cursor()

# %% [markdown]
# ### 2.4 Query Exection dan Load Data

# %%
cursor.execute("SELECT * FROM customers")

results = cursor.fetchall()

# %% [markdown]
# ### 2.5 Display Data

# %%
print("Data Customer dari Database 'alta_task_data_ingestion'")

df_customers = pd.DataFrame(results, columns=['id', 'name', 'email', 'address'])
display(df_customers)
# Out:
# Data Customer dari Database 'alta_task_data_ingestion'
#     id             name                        email  \
# 0    1         John Doe         john.doe@example.com
# 1    2       Jane Smith       jane.smith@example.com
# 2    3  Michael Johnson  michael.johnson@example.com
# 3    4      Emily Brown      emily.brown@example.com
# 4    5   William Taylor   william.taylor@example.com
# 5    6  Sophia Anderson  sophia.anderson@example.com
# 6    7     James Wilson     james.wilson@example.com
# 7    8  Olivia Martinez  olivia.martinez@example.com
# 8    9  Benjamin Garcia  benjamin.garcia@example.com
# 9   10      Ethan Lopez      ethan.lopez@example.com
# 10  11   Emma Rodriguez   emma.rodriguez@example.com
# 11  12        Mason Lee        mason.lee@example.com
# 12  13    Ava Hernandez    ava.hernandez@example.com
# 13  14   Logan Gonzales   logan.gonzales@example.com
# 14  15     Harper Young     harper.young@example.com
# 15  16     Evelyn Evans     evelyn.evans@example.com
# ...

# %% [markdown]
# ## 3. Ambil data pengiriman dari API berikut: https://fakestoreapi.com/products menggunakan requests.

# %% [markdown]
# ### 3.1 Install Library

# %%
# %pip install requests
# Out:
# ...
#
# ...

# %% [markdown]
# ### 3.2 Import Library

# %%
import requests

# %% [markdown]
# ### 3.3 Load Data dan Display Data

# %%
url = "https://fakestoreapi.com/products"

request = requests.get(url).json()

df_products_api = pd.DataFrame(request)
display(df_products_api)
# Out:
#     id                                              title   price  \
# 0    1  Fjallraven - Foldsack No. 1 Backpack, Fits 15 ...  109.95
# 1    2             Mens Casual Premium Slim Fit T-Shirts    22.30
# 2    3                                 Mens Cotton Jacket   55.99
# 3    4                               Mens Casual Slim Fit   15.99
# 4    5  John Hardy Women's Legends Naga Gold & Silver ...  695.00
# 5    6                       Solid Gold Petite Micropave   168.00
# 6    7                         White Gold Plated Princess    9.99
# 7    8  Pierced Owl Rose Gold Plated Stainless Steel D...   10.99
# 8    9  WD 2TB Elements Portable External Hard Drive -...   64.00
# 9   10  SanDisk SSD PLUS 1TB Internal SSD - SATA III 6...  109.00
# 10  11  Silicon Power 256GB SSD 3D NAND A55 SLC Cache ...  109.00
# 11  12  WD 4TB Gaming Drive Works with Playstation 4 P...  114.00
# 12  13  Acer SB220Q bi 21.5 inches Full HD (1920 x 108...  599.00
# ...

# %% [markdown]
# ## 4. Simpan semua data yang diingest ke dalam Pandas DataFrame dan ekspor ke file Parquet

# %% [markdown]
# ### 4.1 Simpan data ke Pandas DataFrame

# %%
# Masing-masing data dari file csv, excel, database, dan api sudah disimpan dalam pandas data frame di setiap nomor soalnya

# %% [markdown]
# ### 4.2 Install Library

# %%
# %pip install pyarrow
# %pip install fastparquet
# Out:
# ...
#
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### 4.3 Export Data ke File Parquet

# %%
# No 1
df_transactions.to_parquet('file/transactions.parquet')
df_products.to_parquet('file/products.parquet')

# No 2
df_customers.to_parquet('file/customers.parquet')

# No 3
df_products_api.to_parquet('file/product_api.parquet')
